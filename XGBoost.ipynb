# %%
import xgboost as xgb
# read in data
dtrain = xgb.DMatrix('demo/data/agaricus.txt.train')
dtest = xgb.DMatrix('demo/data/agaricus.txt.test')
# specify parameters via map
param = {'max_depth':2, 'eta':1, 'objective':'binary:logistic' }
num_round = 2
bst = xgb.train(param, dtrain, num_round)
# make prediction
preds = bst.predict(dtest)
# Out:
# [21:35:56] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1662013816914/work/src/data/data.cc:873: No format parameter is provided in input uri.  Choosing default parser in dmlc-core.  Consider providing a uri parameter like: filename?format=csv
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# Cell In [1], line 3
#       1 import xgboost as xgb
#       2 # read in data
# ----> 3 dtrain = xgb.DMatrix('demo/data/agaricus.txt.train')
#       4 dtest = xgb.DMatrix('demo/data/agaricus.txt.test')
#       5 # specify parameters via map
#
# File ~/.conda/envs/d2l/lib/python3.9/site-packages/xgboost/core.py:575, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     573 for k, arg in zip(sig.parameters, args):
#     574     kwargs[k] = arg
# --> 575 return f(**kwargs)
#
# File ~/.conda/envs/d2l/lib/python3.9/site-packages/xgboost/core.py:686, in DMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical)
#     683     assert self.handle is not None
#     684     return
# --> 686 handle, feature_names, feature_types = dispatch_data_backend(
#     687     data,
#     688     missing=self.missing,
#     689     threads=self.nthread,
#     690     feature_names=feature_names,
#     691     feature_types=feature_types,
#     692     enable_categorical=enable_categorical,
#     693 )
#     694 assert handle is not None
#     695 self.handle = handle
#
# File ~/.conda/envs/d2l/lib/python3.9/site-packages/xgboost/data.py:883, in dispatch_data_backend(data, missing, threads, feature_names, feature_types, enable_categorical)
#     880     return _from_numpy_array(data, missing, threads, feature_names,
#     881                              feature_types)
#     882 if _is_uri(data):
# --> 883     return _from_uri(data, missing, feature_names, feature_types)
#     884 if _is_list(data):
#     885     return _from_list(data, missing, threads, feature_names, feature_types)
#
# File ~/.conda/envs/d2l/lib/python3.9/site-packages/xgboost/data.py:798, in _from_uri(data, missing, feature_names, feature_types)
#     796 handle = ctypes.c_void_p()
#     797 data = os.fspath(os.path.expanduser(data))
# --> 798 _check_call(_LIB.XGDMatrixCreateFromFile(c_str(data),
#     799                                          ctypes.c_int(1),
#     800                                          ctypes.byref(handle)))
#     801 return handle, feature_names, feature_types
#
# File ~/.conda/envs/d2l/lib/python3.9/site-packages/xgboost/core.py:246, in _check_call(ret)
#     235 """Check the return value of C API call
#     236
#     237 This function will raise exception when error occurs.
#    (...)
#     243     return value from API calls
#     244 """
#     245 if ret != 0:
# --> 246     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#
# XGBoostError: [21:35:56] /home/conda/feedstock_root/build_artifacts/xgboost-split_1662013816914/work/src/data/data.cc:879: Encountered parser error:
# [21:35:56] /home/conda/feedstock_root/build_artifacts/xgboost-split_1662013816914/work/dmlc-core/src/io/local_filesys.cc:104: LocalFileSystem.ListDirectory demo/data error: No such file or directory
# Stack trace:
#   [bt] (0) /home/studio-lab-user/.conda/envs/d2l/lib/libxgboost.so(+0xb3a3f) [0x7fe57e9b2a3f]
#   [bt] (1) /home/studio-lab-user/.conda/envs/d2l/lib/libxgboost.so(dmlc::io::LocalFileSystem::ListDirectory(dmlc::io::URI const&, std::vector<dmlc::io::FileInfo, std::allocator<dmlc::io::FileInfo> >*)+0x890) [0x7fe57edd4f90]
#   [bt] (2) /home/studio-lab-user/.conda/envs/d2l/lib/libxgboost.so(dmlc::io::InputSplitBase::ConvertToURIs(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const&)+0xa9d) [0x7fe57edd1c9d]
#   [bt] (3) /home/studio-lab-user/.conda/envs/d2l/lib/libxgboost.so(dmlc::io::InputSplitBase::InitInputFileInfo(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const&, bool)+0x4c) [0x7fe57edd29fc]
#   [bt] (4) /home/studio-lab-user/.conda/envs/d2l/lib/libxgboost.so(dmlc::io::InputSplitBase::Init(dmlc::io::FileSystem*, char const*, unsigned long, bool)+0x70) [0x7fe57edd3080]
#   [bt] (5) /home/studio-lab-user/.conda/envs/d2l/lib/libxgboost.so(dmlc::InputSplit::Create(char const*, char const*, unsigned int, unsigned int, char const*, bool, int, unsigned long, bool)+0xd4f) [0x7fe57edaafaf]
#   [bt] (6) /home/studio-lab-user/.conda/envs/d2l/lib/libxgboost.so(dmlc::InputSplit::Create(char const*, unsigned int, unsigned int, char const*)+0x1f) [0x7fe57edab99f]
#   [bt] (7) /home/studio-lab-user/.conda/envs/d2l/lib/libxgboost.so(dmlc::Parser<unsigned int, float>* dmlc::data::CreateLibSVMParser<unsigned int, float>(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const&, std::map<std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> >, std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> >, std::less<std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > >, std::allocator<std::pair<std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const, std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > > > > const&, unsigned int, unsigned int)+0x31) [0x7fe57ed6c711]
#   [bt] (8) /home/studio-lab-user/.conda/envs/d2l/lib/libxgboost.so(+0x453dca) [0x7fe57ed52dca]
#
#
# Stack trace:
#   [bt] (0) /home/studio-lab-user/.conda/envs/d2l/lib/libxgboost.so(+0xb3a3f) [0x7fe57e9b2a3f]
#   [bt] (1) /home/studio-lab-user/.conda/envs/d2l/lib/libxgboost.so(+0x96984) [0x7fe57e995984]
#   [bt] (2) /home/studio-lab-user/.conda/envs/d2l/lib/libxgboost.so(XGDMatrixCreateFromFile+0x120) [0x7fe57e9b0aa0]
#   [bt] (3) /home/studio-lab-user/.conda/envs/d2l/lib/python3.9/lib-dynload/../../libffi.so.8(+0x6a4a) [0x7fe5ce6ada4a]
#   [bt] (4) /home/studio-lab-user/.conda/envs/d2l/lib/python3.9/lib-dynload/../../libffi.so.8(+0x5fea) [0x7fe5ce6acfea]
#   [bt] (5) /home/studio-lab-user/.conda/envs/d2l/lib/python3.9/lib-dynload/_ctypes.cpython-39-x86_64-linux-gnu.so(+0x132ad) [0x7fe5ce6c62ad]
#   [bt] (6) /home/studio-lab-user/.conda/envs/d2l/lib/python3.9/lib-dynload/_ctypes.cpython-39-x86_64-linux-gnu.so(+0x12954) [0x7fe5ce6c5954]
#   [bt] (7) python(_PyObject_MakeTpCall+0x347) [0x55ef3d6dfbc7]
#   [bt] (8) python(_PyEval_EvalFrameDefault+0x5351) [0x55ef3d6dbc91]
